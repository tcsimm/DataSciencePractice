# %%
# Queries

import pandas as pd
import sqlite3

conn = sqlite3.connect("/Users/thomassimmons/Downloads/chinook-database-master/ChinookDatabase/DataSources/Chinook_Sqlite.sqlite")

# %%
pd.read_sql("""SELECT FirstName, LastName, Country
            FROM Customer
            WHERE Country = 'USA';
            """, conn)
# Out:
#    FirstName    LastName Country
# 0      Frank      Harris     USA
# 1       Jack       Smith     USA
# 2   Michelle      Brooks     USA
# 3        Tim       Goyer     USA
# 4        Dan      Miller     USA
# 5      Kathy       Chase     USA
# 6    Heather     Leacock     USA
# 7       John      Gordon     USA
# 8      Frank     Ralston     USA
# 9     Victor     Stevens     USA
# 10   Richard  Cunningham     USA
# 11   Patrick        Gray     USA
# 12     Julia     Barnett     USA

# %%
pd.read_sql("PRAGMA table_info", conn)
# Out:
# Empty DataFrame
# Columns: [cid, name, type, notnull, dflt_value, pk]
# Index: []

# %%
pd.read_sql("""SELECT COUNT(*) AS total_invoices
            FROM Invoice;""", conn)
# Out:
#    total_invoices
# 0             412

# %%
pd.read_sql(""" SELECT COUNT(TOTAL) AS avg_invoice_total
            FROM Invoice;""", conn)
# Out:
#    avg_invoice_total
# 0                412

# %%
pd.read_sql("""WITH RankedInvoices AS (
    SELECT *,
            RANK() OVER (PARTITION BY BillingCountry
            ORDER BY Total DESC) AS Rank
            FROM Invoice
)
SELECT * 
FROM RankedInvoices
WHERE rank <= 3;""", conn)
# Out:
#     InvoiceId  CustomerId          InvoiceDate         BillingAddress  \
# 0         348          56  2013-03-10 00:00:00     307 Macacha Güemes
# 1         403          56  2013-11-08 00:00:00     307 Macacha Güemes
# 2         164          56  2010-12-17 00:00:00     307 Macacha Güemes
# 3         250          55  2012-01-01 00:00:00      421 Bourke Street
# 4         305          55  2012-08-31 00:00:00      421 Bourke Street
# ..        ...         ...                  ...                    ...
# 80        201          25  2011-05-29 00:00:00  319 N. Frances Street
# 81        103          24  2010-03-21 00:00:00  162 E Superior Street
# 82         54          53  2009-08-16 00:00:00           113 Lupus St
# 83        152          54  2010-10-24 00:00:00         110 Raeburn Pl
# 84        369          52  2013-06-11 00:00:00      202 Hoxton Street
#
#      BillingCity BillingState  BillingCountry BillingPostalCode  Total  Rank
# ...

# %%
import pandas as pd
import numpy as np

# Load sample data
df = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv")

# %%
# Handle missing values
df.fillna(method="ffill", inplace=True)
# Out:
# /var/folders/kf/nt6wlgn90dvc9wsk7ttkqs4w0000gn/T/ipykernel_4245/2035664652.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)

# %%
# Normalize numeric features
df['sepal_length_norm'] = (df['sepal_length'] - df['sepal_length'].mean()) / df['sepal_length'].std()

# %%
# Convert species to category
df['species_encoded'] = df['species'].astype('category').cat.codes

# %%
# New imports for ML
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
# Features and target
X = df[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]
y = df['species_encoded']

# %%
# Train/test split
X_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# Train model
model = RandomForestClassifier()
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
# Evaluate
preds = model.predict(x_test)
print("Accuracy:", accuracy_score(y_test, preds))
# Out:
# Accuracy: 0.9333333333333333

# %%
import boto3

# Create SageMaker client
sagemaker = boto3.client('sagemaker', region_name='us-east-1')

# list models in SageMaker account
response = sagemaker.list_models()
for model in response['Models']:
    print(model['ModelName'])
# Out:
# ---------------------------------------------------------------------------
# NoCredentialsError                        Traceback (most recent call last)
# Cell In[31], line 7
#       4 sagemaker = boto3.client('sagemaker', region_name='us-east-1')
#       6 # Example: list models in your SageMaker account
# ----> 7 response = sagemaker.list_models()
#       8 for model in response['Models']:
#       9     print(model['ModelName'])
#
# File /opt/anaconda3/lib/python3.12/site-packages/botocore/client.py:595, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     591     raise TypeError(
#     592         f"{py_operation_name}() only accepts keyword arguments."
#     593     )
#     594 # The "self" in this scope is referring to the BaseClient.
# --> 595 return self._make_api_call(operation_name, kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/botocore/context.py:123, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
# ...
