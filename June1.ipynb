# %%
import pandas as pd
import numpy as np

# %%
arr = np.array([1,2,3,4,5])
np.average(arr)

arr = arr.astype('int64')

# %%
np.average(arr)
# Out:
# 3.0

# %%
print(arr)
# Out:
# [1 2 3 4 5]

# %%
arr1 = np.array([1,2,3,4])
np.average(arr1)
# Out:
# 2.5

# %%
print(type(arr))
# Out:
# <class 'numpy.ndarray'>

# %%
df = pd.read_csv("/Users/thomassimmons/Downloads/titanic.csv")

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age'].fillna(df['Age'].median(), inplace=True)
# Out:
# /var/folders/kf/nt6wlgn90dvc9wsk7ttkqs4w0000gn/T/ipykernel_15487/1933487976.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].median(), inplace=True)

# %%
df['Age'] = df['Age'].astype('int64')

# %%
df['Age']
# Out:
# 0      22
# 1      38
# 2      26
# 3      35
# 4      35
#        ..
# 886    27
# 887    19
# 888    28
# 889    26
# 890    32
# Name: Age, Length: 891, dtype: int64

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.drop(columns=['Embarked'], inplace=True)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df['Age'])
plt.xlabel("Counts")
plt.ylabel("Ages")
plt.title("Ages of Passengers")
plt.show()

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# dtype: int64

# %%
df.drop(columns=['Cabin'], inplace=True)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# dtype: int64

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age              int64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# dtype: object

# %%
df.groupby('Survived')['Pclass'].mean()
# Out:
# Survived
# 0    2.531876
# 1    1.950292
# Name: Pclass, dtype: float64

# %%
df.groupby('Sex')['Survived'].mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
df['Age'].hist(bins=30)
plt.title("Ages among passengers")
plt.xlabel("Ages")
plt.ylabel("Frequency")
plt.show()

# %%
df.groupby('Sex')['Survived'].mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
df.groupby('Pclass')['Survived'].mean()
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %%
df['Pclass'] = df['Pclass'].astype('str')

# %%
import seaborn as sns

# %%
sns.barplot(x='Sex', y='Survived', data=df)
plt.title("Survival rate by gender")
plt.xlabel("Gender")
plt.ylabel("Survival Rate")
plt.show()

# %%
sns.barplot(x='Sex', y='Survived', data=df)
plt.title("Sexes of survived passengers")
plt.xlabel("Sex")
plt.ylabel("Survival rate")
plt.show()

# %%
sns.barplot(x='Sex', y='Survived', data=df)
plt.xlabel("Sex")
plt.ylabel("Survived")
plt.title("Survival rate by sex")
plt.show()

# %%
sns.barplot(x='Pclass', y='Survived', data=df)
plt.title("Survival rate by class")
# Out:
# Text(0.5, 1.0, 'Survival rate by class')

# %%
import sqlite3
